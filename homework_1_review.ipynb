# %% [markdown]
# # Homework 1
#
# ## Feedback/Comments
#
# 1. Overall good job.
# 2. Everyone figured out the usage of international units, and the conversion of grams to kilograms
# 3. It was exciting to see everyone's level of coding
# 4. A few submissions could not be ran (e.g. 1 assignment was name 'mass2energy.py', but should have been 'mass2energy.ipynb'
# 5. Everyone who turned something in passed.
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# ## Specific Examples and Feedback

# %%
mass = 0.500
energy = 0.500 * 299792458 * 299792458

print("%f kg of mass contains %d J (joules) of energy" % (mass, energy))
# Out:
# 0.500000 kg of mass contains 44937758936840880 J (joules) of energy

# %% [markdown]
# ## Feedback/Comments
#
# 1. Without context of the assignment, it is somewhat difficult to understand what is happening.
# 2. Repeating the value of the speed of light - introduces possiblity of introducing error
# 3. %f and %d for float and integer values - what is the reason behind this?
# 4. Why add additional digits to 500 grams?

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## mass2energy
# Task:
# Write a program (e.g. 'mass2energy.py') that calculates the amount of energy that is equivalent to 500 grams of mass.
#
#
# 1.   Use Einstein's $E=mc^2$, where 'E' is energy, 'm' is mass weight and 'c' is the speed of light
# 2.  Report the answer in the International Unit for Energy

# %%
## First Assignment: converting grams of mass -> amount of energy

## Declaring variables
mass_grams = 500
mass_kg = 500 / 1000
lightspeed = 299792458

energy_joule = mass_kg * lightspeed ** 2

print("The equivalent amount of energy for {} grams is {} joule.".format(mass_grams, energy_joule))
# Out:
# The equivalent amount of energy for 500 grams is 4.493775893684088e+16 joule.

# %% [markdown]
# ## Feedback/Comments
#
# 1. Simple and clear variables (i.e. very readable)
# 2. Good commenting (maybe a *bit* too much - avoid what is obvious)
#
# Take home message: demonstrates clear thought process, and concise thinking

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %%
import math

Mass = 0.5
c = 299792458
E = Mass*math.pow(c,2)
print(E, 'Joule')
# Out:
# 4.493775893684088e+16 Joule

# %% [markdown]
# ## Feedback/Comments
#
# 1. Simple
# 2. Doesn't provide the reader/user any guidence (e.g. mass should be kg; c is the speed of light)
# 3. Uses the math librarry (fine, but unnecessary)

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %%
# -*- coding: utf-8 -*-
"""mass2energy.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://########
"""

from scipy.constants import speed_of_light

e = 0.5*speed_of_light**2

print(str(e) + ' kg⋅m²⋅s-²')
# Out:
# 4.493775893684088e+16 kg⋅m²⋅s-²

# %% [markdown]
# ## Feedback/Comments
#
# 1. Good Usage of the triple quote comment
# 2. Usage of scipy's collection of constants (reduces possible errors)
# 3. However, not very reusable - the mass is hard coded into the energy equation

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %%
#c= 299792458 m/s
#M=0.5 kg
def energy():
    c=299792458
    M= 0.5
    E=M*c**2
    print("E=",E," J")
    
energy()
# Out:
# E= 4.493775893684088e+16  J

# %% [markdown]
# ## Feedback/Comments
#
# 1. Uses one letter variable names [Scientific Programming](https://colab.research.google.com/github/karlkirschner/2020_Scientific_Programming/blob/master/scientific_programming.ipynb#best_practice_work).
# 2. Provides no explanation of what is going on (e.g. what exactly is 'c= 299792458 m/s' - only in the context of the homework instructions would this be understandable)
# 3. A better print statement: print('E = {0} J'.format(E))
# 4. Inconsistent spacing (e.g. 'M= 0.5' vs. 'c=299792458')
# 5. Does not provide an answer when executed.
#
# Take home mesage: Leaves the impression of not being careful

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %%
##mass2energy

m = 0.5
c = 3 * (10**8)
E = m * (c**2) 

print ('With a mass of 0.5 kg, E is: {0} Joule'.format(E))
# Out:
# With a mass of 0.5 kg, E is: 4.5e+16 Joule

# %% [markdown]
# ## Feedback/Comments
#
# 1. Uses one letter variable names
# 2. Provides no explanation of what is going on
# 3. Rounds a highly precise contants to one digit - DON'T do this because it introduces errors!

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Mar 30 16:44:10 2020

@author: ######
"""



#### First function returns a float
#### Second function returns a String (char array)



### First
### mass must be in kg!
energy = lambda mass : mass * (299792458**2)


### Second 
### The mass value is set to .5 by default but can be changed by calling the function like this: energy(your_value)
### Value must be in kg by default
### To get the right result using gramm set the second value to False
### i.e: energyy(your_value_in_gramm, False) or enegryy(in_kg = False, mass = your_value_in_gramm)
def energyy(mass = None, in_kg = True):
    
    if (not in_kg):
        mass = mass/1000
    
    output = ""
    light_speed = 299792458 #m/s
    
    energy = mass * (light_speed)**2
    
    output = "Mass : {0} kg \nSpeed of Light : {1} m/s^2 \nEnergy : {2} Joule ((kg * m^2) / s^2)".format(mass, light_speed, energy)
    return output

print(energyy(.5),"\n\n",energyy(500, False))
#print(energyy(700, False), "\n\n", energyy(.7))
# Out:
# Mass : 0.5 kg
# Speed of Light : 299792458 m/s^2
# Energy : 4.493775893684088e+16 Joule ((kg * m^2) / s^2)
#
#  Mass : 0.5 kg
# Speed of Light : 299792458 m/s^2
# Energy : 4.493775893684088e+16 Joule ((kg * m^2) / s^2)

# %% [markdown]
# ## Feedback/Comments
#
# 1. Has an internal check ('if (not in_kg)') - but is set to 'True'
# 2. Good variable names
# 3. Spelling error (e.g. 'energyy', 'enegryy', 'gramm')
# 4. No reason to create a function when you set the variables in the statement.
# 5. Redundant comments (e.g. 'mass must be in kg!' and 'Value must be in kg by default')
# 6. The speed of light is set several times
#
# Take home message: too verbose, not concisely done. (More is not always more.)

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %%
def mass_to_energy(mass):
    energy = 0
    speed_of_light = 3 * pow(10, 8)
    mass_to_kg = mass / 1000
    energy = mass_to_kg * speed_of_light * speed_of_light
    return "Amount of energy that is equivalent to {} grams of mass is {}(N.m) or {}(m2∙kg∙s−2)" \
        .format(mass, energy, energy)


mass = 500
print()
print(mass_to_energy(mass))

# %% [markdown]
# ## Feedback/Comments
#
# 1. Sets variable to an initial value (i.e. 'energy = 0')
# 2. Should set 'energy = None' - then write a check to make sure user provided a value such that energy is not 'None"
# 3. Good variable names - doesn't need to provide additional comments
# 4. Defines a function, forcing it take one input (i.e. 'mass') - allows for reusability
# 5. Good return statement (i.e. usage of 'format' command)
# 6. Rounds a constant - not scientific !!! (my souls cried a little)
#
# Take home message - solid work, leaves an impression of a critical thinker

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %%
def einsteins_mass_energy_equivalence(mass):
    """ This function calculates the energy from Einsteins Mass-energy equivalence formula E=mc^2
        input: mass - the mass of an "object" in kg
        return: energy - the equivalent energy to the "objects" mass   """
    
    #static variable for speed_of_light in m/s
    speed_of_light=299792458

    energy=mass*speed_of_light**2

    print("The amount of equivalent energy to",mass,"kg (kilograms) of mass is",energy,"J (joules)")
    return energy

mass=500*10**-3
einsteins_mass_energy_equivalence(mass)
# Out:
# The amount of equivalent energy to 0.5 kg (kilograms) of mass is 4.493775893684088e+16 J (joules)
# 4.493775893684088e+16

# %% [markdown]
# ## Feedback/Comments
#
# 1. Good comment section (i.e. 'input:' and 'return' statements; however, could define the energy unit as joules)
# 2. Forces the function to take one input (i.e. 'mass') - allows for reusability
# 3. Print statement would be better with the usage of a 'format' - and moving it out of the function itself
#
# Take home message - solid work, leaves an impression of a critical thinker

# %% [markdown]
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %%
## If you just want the raw energy value, use this method as is,
##  otherwise use the alternative mass which takes user input or defaults to 0.5 kg

def mass2energy():
    
    ## uses either user input or defaults to a mass of 0.5 kg
    #print('This method calculates the amount of Energy in a given mass according to E = mc², \
    #  rounded up to 4 digits.\nPlease enter the weight you want to be converted in kg below (default: 0.5 kg):')
    # mass = float(input() or 0.5)
    
    mass = 0.5
    speed_of_light = 2.9979 * 10**8
    
    ## calculates the energy, rounded up to 4 digits (E = mc²)
    
    energy = format(mass * speed_of_light**2, '.4g')

    #result = 'The amount of energy that is equivalent to {0} kg of mass is {1} J'.format(mass,energy)
    #print(result)
    return energy

# %%
mass2energy()
# Out:
# '4.494e+16'

# %% [markdown]
# ## Feedback/Comments
#
# 1. Creates a function ease of reuse - notice how it is called
# 2. But why are the variable values hard-coded inside the function? This removes the function's reusability
# 3. Rounds a constant
# 4. Has commented-out print statements (maybe for error testing during development)
# 5. Long lines that scroll off the page
# 6. Rounds the answer to 4 digits - interesting idea, why?
#
# Take home message: logical, thoughtful, leave the impression that some critical thinking went into making this code, but the reasons why choices were made are unclear
